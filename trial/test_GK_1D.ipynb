# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters for Gaussian convolution
sigma = 10
kernel_size = int(3 * sigma)  # Typical choice for the kernel size
gaussian_kernel = gaussian_kernel(kernel_size, sigma)

# Perform Gaussian convolution to smooth the density
smoothed_pi_x = convolve(pi_x, gaussian_kernel, mode='same')

# Plot the potential, equilibrium density, and smoothed density
plt.figure(figsize=(10, 6))

# Plot potential
plt.plot(x, potential(x), label='Potential V(x)', color='blue')

# Plot equilibrium density
plt.plot(x, pi_x, label='Equilibrium Density π(x)', color='green')

# Plot smoothed equilibrium density
plt.plot(x, smoothed_pi_x, label='Smoothed Density', color='red')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Potential, Equilibrium Density, and Smoothed Density')
plt.xlim(-2, 2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters for Gaussian convolution
sigma = 0.5  # Example value for sigma
kernel_size = int(3 * sigma)  # Typical choice for the kernel size
gaussian_kernel = gaussian_kernel(kernel_size, sigma)

# Perform Gaussian convolution to smooth the density
smoothed_pi_x = convolve(pi_x, gaussian_kernel, mode='same')

# Plot the potential
plt.figure(figsize=(10, 6))
plt.plot(x, potential(x), label='Potential V(x)', color='blue')
plt.xlabel('x')
plt.ylabel('V(x)')
plt.title('Potential V(x)')
plt.xlim(-2, 2)
plt.legend()
plt.grid(True)
plt.show()

# Plot the equilibrium density
plt.figure(figsize=(10, 6))
plt.plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
plt.xlabel('x')
plt.ylabel('π(x)')
plt.title('Equilibrium Density π(x)')
plt.xlim(-2, 2)
plt.legend()
plt.grid(True)
plt.show()

# Plot the smoothed density
plt.figure(figsize=(10, 6))
plt.plot(x, smoothed_pi_x, label='Smoothed Density', color='red')
plt.xlabel('x')
plt.ylabel('Smoothed π(x)')
plt.title('Smoothed Density')
plt.xlim(-2, 2)
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Parameters for Gaussian convolution
sigma = 0.2  # Example value for sigma
kernel_size = int(5 * sigma)  # Adjusted kernel size
gaussian_kernel = gaussian_kernel(kernel_size, sigma)

# Perform Gaussian convolution to smooth the density
smoothed_pi_x = convolve(pi_x, gaussian_kernel, mode='same')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot the potential function
axs[0, 0].plot(x, potential(x), label='Potential V(x)', color='blue')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('V(x)')
axs[0, 0].set_title('Potential V(x)')
axs[0, 0].legend()
axs[0, 0].grid(True)
axs[0, 0].set_xlim(-2, 2)

# Plot the equilibrium density
axs[0, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('π(x)')
axs[0, 1].set_title('Equilibrium Density π(x)')
axs[0, 1].legend()
axs[0, 1].grid(True)
axs[0, 1].set_xlim(-2, 2)

# Plot the smoothed density
axs[1, 0].plot(x, smoothed_pi_x, label='Smoothed Density', color='red')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('Smoothed π(x)')
axs[1, 0].set_title('Smoothed Density')
axs[1, 0].legend()
axs[1, 0].grid(True)
axs[1, 0].set_xlim(-2, 2)

# Plot both equilibrium density and smoothed density
axs[1, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[1, 1].plot(x, smoothed_pi_x, label='Smoothed Density', color='red', linestyle='--')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('Density')
axs[1, 1].set_title('Equilibrium and Smoothed Densities')
axs[1, 1].legend()
axs[1, 1].grid(True)
axs[1, 1].set_xlim(-2, 2)

# Adjust layout
plt.tight_layout()

# Save the figure
plt.savefig('density_analysis.png', dpi=300)  # Save as PNG with 300 dpi

# Display the figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Parameters for Gaussian convolution
sigma = 0.2  # Example value for sigma
kernel_size = int(5 * sigma)  # Adjusted kernel size
gaussian_kernel = gaussian_kernel(kernel_size, sigma)

# Perform Gaussian convolution to smooth the density
smoothed_pi_x = convolve(pi_x, gaussian_kernel, mode='same')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot the potential function
axs[0, 0].plot(x, potential(x), label='Potential V(x)', color='blue')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('V(x)')
axs[0, 0].set_title('Potential V(x)')
axs[0, 0].legend()
axs[0, 0].grid(True)
axs[0, 0].set_xlim(-2, 2)

# Plot the equilibrium density
axs[0, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('π(x)')
axs[0, 1].set_title('Equilibrium Density π(x)')
axs[0, 1].legend()
axs[0, 1].grid(True)
axs[0, 1].set_xlim(-2, 2)

# Plot the smoothed density
axs[1, 0].plot(x, smoothed_pi_x, label='Smoothed Density', color='red')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('Smoothed π(x)')
axs[1, 0].set_title('Smoothed Density')
axs[1, 0].legend()
axs[1, 0].grid(True)
axs[1, 0].set_xlim(-2, 2)

# Plot both equilibrium density and smoothed density
axs[1, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[1, 1].plot(x, smoothed_pi_x, label='Smoothed Density', color='red', linestyle='--')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('Density')
axs[1, 1].set_title('Equilibrium and Smoothed Densities')
axs[1, 1].legend()
axs[1, 1].grid(True)
axs[1, 1].set_xlim(-2, 2)

# Adjust layout
plt.tight_layout()

# Save the figure
plt.savefig('density_analysis.png', dpi=300)  # Save as PNG with 300 dpi

# Display the figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# List of bandwidths (sigma values)
sigma_values = [0.2, 0.4, 0.6, 1.0]

# Create a single subplot for smoothed densities
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the equilibrium density
ax.plot(x, pi_x, label='Equilibrium Density π(x)', color='green', linestyle='--')

# Plot smoothed densities for different bandwidths
for sigma in sigma_values:
    kernel_size = int(5 * sigma)  # Adjust kernel size based on sigma
    kernel = gaussian_kernel(kernel_size, sigma)
    smoothed_pi_x = convolve(pi_x, kernel, mode='same')
    ax.plot(x, smoothed_pi_x, label=f'Smoothed Density (σ={sigma})')

# Configure plot
ax.set_xlabel('x')
ax.set_ylabel('Density')
ax.set_title('Equilibrium and Smoothed Densities for Different Bandwidths')
ax.legend()
ax.grid(True)
ax.set_xlim(-2, 2)

# Adjust layout
plt.tight_layout()

# Save the figure
plt.savefig('density_comparison_bandwidths.png', dpi=300)  # Save as PNG with 300 dpi

# Display the figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Generate a discrete distribution of particles (e.g., sample from normal distribution)
np.random.seed(42)
particles = np.random.normal(0, 0.5, 1000)
particle_density, bin_edges = np.histogram(particles, bins=x, density=True)
# To match the length of x, interpolate the bin edges
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
particle_density = np.interp(x, bin_centers, particle_density, left=0, right=0)

# Bandwidth value
sigma = 0.4

# Create Gaussian kernel
kernel_size = int(5 * sigma)  # Adjust kernel size based on sigma
kernel = gaussian_kernel(kernel_size, sigma)
smoothed_particle_density = convolve(particle_density, kernel, mode='same')

# Create a single plot for the densities
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the equilibrium density
ax.plot(x, pi_x, label='Equilibrium Density π(x)', color='orange', linestyle='--')

# Plot smoothed particle density
ax.plot(x, smoothed_particle_density, label=f'Smoothed Particle Density ρ(x) (σ={sigma})', color='blue')

# Configure plot
ax.set_xlabel('x')
ax.set_ylabel('Density')
ax.set_title(f'Equilibrium and Smoothed Particle Densities (σ={sigma})')
ax.legend()
ax.grid(True)
ax.set_xlim(-2, 2)

# Adjust layout
plt.tight_layout()

# Save the figure
plt.savefig('density_comparison_single_bandwidth.png', dpi=300)  # Save as PNG with 300 dpi

# Display the figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve

# Define the potential function V(x)
def potential(x):
    return x**4 - 4*x**2 + 0.2*x

# Calculate the equilibrium density π(x)
def equilibrium_density(x, beta=1.0):
    V_x = potential(x)
    Z = np.trapz(np.exp(-beta * V_x), x)  # Normalization constant
    return np.exp(-beta * V_x) / Z

# Create Gaussian kernel for convolution
def gaussian_kernel(size, sigma):
    kernel = np.linspace(-size, size, 2*size+1)
    kernel = np.exp(-kernel**2 / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel

# Parameters
beta = 1.0
x = np.linspace(-2, 2, 1000)

# Calculate equilibrium density
pi_x = equilibrium_density(x, beta)

# Parameters for Gaussian convolution
sigma = 0.2  # Example value for sigma
kernel_size = int(5 * sigma)  # Adjusted kernel size
gaussian_kernel = gaussian_kernel(kernel_size, sigma)

# Perform Gaussian convolution to smooth the density
smoothed_pi_x = convolve(pi_x, gaussian_kernel, mode='same')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot the potential function
axs[0, 0].plot(x, potential(x), label='Potential V(x)', color='blue')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('V(x)')
axs[0, 0].set_title('Potential V(x)')
axs[0, 0].legend()
axs[0, 0].grid(True)
axs[0, 0].set_xlim(-2, 2)

# Plot the equilibrium density
axs[0, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('π(x)')
axs[0, 1].set_title('Equilibrium Density π(x)')
axs[0, 1].legend()
axs[0, 1].grid(True)
axs[0, 1].set_xlim(-2, 2)

# Plot the smoothed density
axs[1, 0].plot(x, smoothed_pi_x, label='Smoothed Density', color='red')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('Smoothed π(x)')
axs[1, 0].set_title('Smoothed Density')
axs[1, 0].legend()
axs[1, 0].grid(True)
axs[1, 0].set_xlim(-2, 2)

# Plot both equilibrium density and smoothed density
axs[1, 1].plot(x, pi_x, label='Equilibrium Density π(x)', color='green')
axs[1, 1].plot(x, smoothed_pi_x, label='Smoothed Density', color='red', linestyle='--')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('Density')
axs[1, 1].set_title('Equilibrium and Smoothed Densities')
axs[1, 1].legend()
axs[1, 1].grid(True)
axs[1, 1].set_xlim(-2, 2)

# Compute the difference between the densities
density_difference = smoothed_pi_x - pi_x

# Create a new plot for the difference
fig_diff, ax_diff = plt.subplots(figsize=(10, 6))
ax_diff.plot(x, density_difference, label='Difference (Smoothed - Equilibrium)', color='purple')
ax_diff.set_xlabel('x')
ax_diff.set_ylabel('Difference')
ax_diff.set_title('Difference Between Smoothed and Equilibrium Densities')
ax_diff.legend()
ax_diff.grid(True)
ax_diff.set_xlim(-2, 2)

# Adjust layout and save the difference plot
plt.tight_layout()
plt.savefig('density_difference.png', dpi=300)  # Save as PNG with 300 dpi

# Display the figure with all plots
plt.show()
